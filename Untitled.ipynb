# %%
import numpy as np
import matplotlib.pyplot as plt
from visualizer import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
error_boxplot(show=True, save=False)

# %%
plot_test(1, np.random.rand(3000), np.random.rand(400), show=True, save=True, save_path='./')

# %%
time_boxplot(show=True, save=False)

# %%
error_boxplot(show=True, save=False)

# %%
ax.set_title('unko')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-e32feb746b03> in <module>()
# ----> 1 ax.set_title('unko')
#
# AttributeError: 'NoneType' object has no attribute 'set_title'
