# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
from IPython.core.pylabtools import figsize
figsize(15, 5)

# %%
with open('./data/data3.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
for i in range(10):
    plt.plot(data[i, :300], 'b')
    plt.savefig('./images/data_%d'%(i))

# %%
a = np.random.rand(10, 300).tolist()

# %%
np.mean(a, axis=1).shape
# Out:
# (10,)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-2076945207f6> in <module>()
# ----> 1 mean([1, 1])
#
# NameError: name 'mean' is not defined

# %%
with open('./result/rnn/loss_history.pkl', 'rb') as f:
    loss_history = pickle.load(f)
# with open('./train_error.pkl', 'rb') as f:
#     train_error = pickle.load(f)
# with open('./test_error.pkl', 'rb') as f:
#     test_error = pickle.load(f) 
# with open('./time_history.pkl', 'rb') as f:
#     time_history = pickle.load(f)

# %%
ax

# %%
'unko'.upper().lower()
# Out:
# 'unko'

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.array(loss_history).T)
ax.set_title('rnn'.upper())
ax.set_xlabel('epoch')
ax.set_ylabel('MSE')
# Out:
# Text(0,0.5,'MSE')

# %%
ax.set_xlabel

# %%
plt.plot(np.array(loss_history).T)

# %%
ax

# %%
np.array(loss_history).shape
# Out:
# (10, 500)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for i in range(10):
    ax.plot(loss_history[i], label='data%d'%(i))
ax.legend()
ax.set_title('unko')
# Out:
# Text(0.5,1,'unko')

# %%
for i in range(10):
    plt.plot(loss_history[i])

# %%
loss_history.shape
# Out:
# (10, 300)

# %%
np.array(loss_history).shape
# Out:
# (10, 300)

# %%
i_loss_history = loss_history[0]

# %%
plt.plot(train_error)
plt.plot(test_error, 'r')

# %%
error_type = np.r_[['train'] * 10, ['test'] * 10]

# %%
error_type
# Out:
# array(['train', 'train', 'train', 'train', 'train', 'train', 'train',
#        'train', 'train', 'train', 'test', 'test', 'test', 'test', 'test',
#        'test', 'test', 'test', 'test', 'test'], dtype='<U5')

# %%
 df = pd.DataFrame({ 'error_type' : error_type,
                        'error' : np.r_[train_error, test_error] })

# %%
df
# Out:
#        error error_type
# 0   0.127039      train
# 1   0.016485      train
# 2   0.034067      train
# 3   0.018773      train
# 4   0.058875      train
# 5   0.050176      train
# 6   0.128740      train
# 7   0.120197      train
# 8   0.135233      train
# 9   0.170394      train
# 10  0.127941       test
# 11  0.016570       test
# 12  0.034177       test
# 13  0.018817       test
# 14  0.059257       test
# 15  0.050330       test
# 16  0.128904       test
# 17  0.120970       test
# 18  0.135836       test
# 19  0.170808       test

# %%
sns.boxplot(x="error_type", y="error", data=df)

# %%
a = np.random.rand(10)
a.tolist()
# Out:
# [0.8754557552974651,
#  0.5064687097509176,
#  0.5502530521546147,
#  0.25715740478720694,
#  0.6733501053847224,
#  0.5448360738263822,
#  0.09898423137175771,
#  0.9615423939265648,
#  0.14948778475488078,
#  0.6742621307222644]

# %%
rnn_train_error = np.random.rand(10).tolist()
rnn_test_error = np.random.rand(10).tolist()
rnn_error = rnn_train_error + rnn_test_error

lstm_train_error = np.random.rand(10).tolist()
lstm_test_error = np.random.rand(10).tolist()
lstm_error = lstm_train_error + lstm_test_error

qrnn_train_error = np.random.rand(10).tolist()
qrnn_test_error = np.random.rand(10).tolist()
qrnn_error = qrnn_train_error + qrnn_test_error

cnn_train_error = np.random.rand(10).tolist()
cnn_test_error = np.random.rand(10).tolist()
cnn_error = cnn_train_error + cnn_test_error

error = rnn_error + lstm_error + cnn_error + qrnn_error

# %%
len(error)
# Out:
# 80

# %%
model_type = ['rnn']*10*2 + ['lstm']*10*2 + ['cnn']*10*2 + ['qrnn']*10*2

# %%
len(model_type)
# Out:
# 80

# %%
error_type = (['train'] * 10 + ['test'] * 10) * 4

# %%
len(error_type)
# Out:
# 80

# %%
 df = pd.DataFrame({ 
                         'model_type' : model_type,
                         'error_type' : error_type,
                         'error' : error
                         })

# %%
ax = sns.boxplot(x="model_type", y="error", hue="error_type", data=df)

# %%
np.array(time_history).shape
# Out:
# (10, 300)

# %%
np.mean(time_history, axis=1).shape
# Out:
# (10,)

# %%
rnn_time_history = np.mean(time_history, axis=1).tolist()
lstm_time_history = np.mean(time_history, axis=1).tolist()
qrnn_time_history = np.mean(time_history, axis=1).tolist()
cnn_time_history = np.mean(time_history, axis=1).tolist()

# %%
lstm_time_history
# Out:
# [0.19272589445114136,
#  0.19028311411539714,
#  0.19095881144205729,
#  0.1872317369778951,
#  0.18625365177790323,
#  0.1870427409807841,
#  0.19062026023864745,
#  0.18913689692815144,
#  0.1874666404724121,
#  0.1868720070521037]

# %%
def time_boxplot(rnn_time, lstm_time, cnn_time, qrnn_time, show=False, save=False, save_path=''):
    time_ = rnn_time + lstm_time + cnn_time + qrnn_time
    len_ = len(time_)
    print(len_)
    iter_ = int(len_/4)
    model_type = ['rnn']* iter_ + ['lstm'] * iter_ + ['cnn'] * iter_ + ['qrnn'] * iter_
    
    data =  pd.DataFrame({'model_type' : model_type, 'time' : time_})
    ax = sns.boxplot(x="model_type", y='time', data=data)
    show_save(show, save, save_path)

# %%
time_boxplot(rnn_time_history, lstm_time_history, cnn_time_history, qrnn_time_history, show=True)
# Out:
# 40

# %%
plt.plot(np.mean(time_history, axis=1))

# %% [markdown]
# # utils.py

# %%
import os

# %%
def load_error(model):
    train_error_path = os.path.join('./result', model, 'train_error.pkl')
    test_error_path = os.path.join('./result', model, 'test_error.pkl')
    with open(train_error_path, 'rb') as f:
        train_error= pickle.load(f)
    with open(test_error_path, 'rb') as f:
        test_error= pickle.load(f)
        
    error = train_error + test_error
    return error

# %%
def load_time_history(model):
    path = os.path.join('./result', model, 'time_history.pkl')
    with open(path, 'rb') as f:
        time_history= pickle.load(f)
        
    return time_history

# %%
train_error_path = os.path.join('./result', 'rnn', 'time_history.pkl')
with open(train_error_path, 'rb') as f:
        time_history= pickle.load(f)

# %%
error_boxplot(show=True)

# %%
sns.set_style('darkgrid')
sns.set_context('poster')

# %%
error_boxplot(show=True)
time_boxplot(show=True)
# Out:
# 40

# %%
print('----------')
print('model: %s - data: %d/10'%('rnn', 5))
# Out:
# ----------
# model: rnn - data: 5/10

# %%
def show_save(show, save, save_path):
    if save:
        plt.savefig(save_path)
        
    if show:
        plt.show()
    else:
        plt.close()

# %%
def error_boxplot(show=False, save=False, save_path=''):
    rnn_error = load_error('rnn')
    lstm_error = load_error('lstm')
    cnn_error = load_error('cnn')
    qrnn_error = load_error('qrnn')
    error = rnn_error + lstm_error + cnn_error + qrnn_error
    
    len_ = len(error)
    iter_ = int(len_/8)
    model_type = ['RNN']* iter_ * 2 + ['LSTM'] * iter_ * 2 + ['CNN'] * iter_*2 + ['QRNN'] * iter_*2 
    error_type = (['train'] * iter_ + ['test'] * iter_) * 4
    
    data =  pd.DataFrame({'model' : model_type, 'type' : error_type, 'MSE' : error})
    ax = sns.boxplot(x="model", y="MSE", hue="type", data=data)
    show_save(show, save, save_path)

# %%
time_boxplot(show=True)
# Out:
# 40

# %%
'data%s.png'%(9)
# Out:
# 'data9.png'

# %%
def time_boxplot(show=False, save=False, save_path=''):
    rnn_time = load_time_history('rnn')
    lstm_time = load_time_history('lstm')
    cnn_time = load_time_history('cnn')
    qrnn_time = load_time_history('qrnn')
    
    time_ = rnn_time + lstm_time + cnn_time + qrnn_time
    len_ = len(time_)
    print(len_)
    iter_ = int(len_/4)
    model_type = ['rnn']* iter_ + ['lstm'] * iter_ + ['cnn'] * iter_ + ['qrnn'] * iter_
    
    data =  pd.DataFrame({'model_type' : model_type, 'time [sec/epoch]' : time_})
    ax = sns.boxplot(x="model_type", y='time [sec/epoch]', data=data)
    show_save(show, save, save_path)

# %%
error_boxplot(rnn_error, lstm_error, cnn_error, qrnn_error, show=True)

# %%
time_boxplot(rnn_time_history, lstm_time_history, cnn_time_history, qrnn_time_history, show=True)
