# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
with open('./loss_history.pkl', 'rb') as f:
    loss_history = pickle.load(f)
with open('./train_error.pkl', 'rb') as f:
    train_error = pickle.load(f)
with open('./test_error.pkl', 'rb') as f:
    test_error = pickle.load(f) 
with open('./time_history.pkl', 'rb') as f:
    time_history = pickle.load(f)

# %%
np.array(loss_history).shape
# Out:
# (10, 300)

# %%
i_loss_history = loss_history[0]

# %%
for i in range(10):
    plt.plot(loss_history[0])
    plt.show()

# %%
plt.plot(train_error)
plt.plot(test_error, 'r')

# %%
error_type = np.r_[['train'] * 10, ['test'] * 10]

# %%
error_type
# Out:
# array(['train', 'train', 'train', 'train', 'train', 'train', 'train',
#        'train', 'train', 'train', 'test', 'test', 'test', 'test', 'test',
#        'test', 'test', 'test', 'test', 'test'], dtype='<U5')

# %%
 df = pd.DataFrame({ 'error_type' : error_type,
                        'error' : np.r_[train_error, test_error] })

# %%
df
# Out:
#        error error_type
# 0   0.431386      train
# 1   0.497885      train
# 2   0.585686      train
# 3   0.598686      train
# 4   0.451143      train
# 5   0.513162      train
# 6   0.451498      train
# 7   0.531900      train
# 8   0.546804      train
# 9   0.506834      train
# 10  0.431162       test
# 11  0.497524       test
# 12  0.585024       test
# 13  0.598143       test
# 14  0.450879       test
# 15  0.512654       test
# 16  0.451333       test
# 17  0.531562       test
# 18  0.546656       test
# 19  0.506443       test

# %%
sns.boxplot(x="error_type", y="error", data=df)
